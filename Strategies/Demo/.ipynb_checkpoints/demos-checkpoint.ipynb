# %%
import sys
sys.path.append('../../')
from Backtest import Backtest,Position,Bid
import pandas as pd
import matplotlib.pyplot as plt
import random
import warnings
#warnings.filterwarnings("ignore")

# %% [markdown]
# # Bid Class Demo
# ## intialize a Bid instance with four variables
# - ticker
# - shares
# - price
# - bid_type (1 as buy, 0 as sell)

# %%
# a bid to buy 100 shares of Apple at $163.43
buy_apple_100 = Bid(ticker = "AAPL", shares = 100, price = 163.43, bid_type = 1)

#the show method could be used for debugging
buy_apple_100.show()
# Out:
# ---------------
# Buying:
# Ticker: AAPL
# Shares: 100
# Price: 163.43
# ---------------

# %% [markdown]
# #

# %% [markdown]
# # Position class demo
# ## intialize a Position  instance with a bid instance

# %%
apple_position = Position(buy_apple_100)
apple_position.show()
# Out:
# Ticker: AAPL
# Shares_held: 100
# Latest_price: 163.43
# weighted_average_cost: 163.43
# ----------------
# Purchasing History
# Price	Shares
# 163.43	100

# %% [markdown]
# ## Change the position with another bid

# %%
buy_apple_50 = Bid(ticker = "AAPL", shares = 50, price = 163.13, bid_type = 1)
apple_position.change_position(buy_apple_50)
apple_position.show()
# Out:
# Ticker: AAPL
# Shares_held: 150
# Latest_price: 163.13
# weighted_average_cost: 163.33
# ----------------
# Purchasing History
# Price	Shares
# 163.43	100
# 163.13	50

# %% [markdown]
# ## Selling a stock

# %%
sell_apple_100 = Bid(ticker = 'AAPL', shares = 100, price = 165.24, bid_type = 0)

#if selling a stock, the change_position method will return a cost
#this cost will be the lowest part of costs in purchasing history 
cost_of_buying_100 = apple_position.change_position(sell_apple_100)
apple_position.show()
# Out:
# Ticker: AAPL
# Shares_held: 50
# Latest_price: 165.24
# weighted_average_cost: 163.43
# ----------------
# Purchasing History
# Price	Shares
# 163.43	50

# %%
income = sell_apple_100.shares * sell_apple_100.price
print("Income: ", income)
print("Cost: ", cost_of_buying_100)
print("Pnl for this single trade: ", income - cost_of_buying_100 )
# Out:
# Income:  16524.0
# Cost:  16328.0
# Pnl for this single trade:  196.0

# %%
apple_position.change_position(sell_apple_100)
# Out:
# Try to sell 100 shares, but only got 50 shares.
# 0

# %% [markdown]
# #

# %% [markdown]
# # A demo strategy
# ## Randomly buy 10 stocks at 9:30 everyday and sell at 16:00
# ## a strategy is defined as a class, and it must have a predict method that returns a list of Bid instances
# ## a strategy function has five parameters, which are:
# - ti: current datetime
# - df: all historical data up to ti
# - positions: a dictionary of all current positions (k: string of ticker, v: an instance of this ticker's Position)
# - cash: cash avaliable
# - full_data: dataframe with OHLCV
#
# ## *This is the part where you implement your strategy

# %%
class DemoStrategy:
    def predict(ti,df,positions,cash,full_data):
#         if ti.minute == 0 or ti.minute == 30:
#             print("================={}=================".format(ti))
        bid_list = []

        #buy
        if ti.hour == 9 and ti.minute == 30:
            for i in range(10):
                ticker = random.choice(df.columns)
                bid = Bid(ticker = ticker, shares = 100, price = df.iloc[-1][ticker],bid_type = 1)
                bid_list.append(bid)
                #bid.show()
            return bid_list

        #sell
        if ti.hour == 16 and ti.minute == 0:
            #for all current positions
            for pos in positions.values():
                bid = Bid(ticker = pos.ticker,shares = pos.shares,price = df.iloc[-1][pos.ticker],bid_type = 0)
                bid_list.append(bid)
                #bid.show()
            return bid_list
        return bid_list

# %% [markdown]
# # Load sample data

# %%
def get_data(tickers,length,interval):
    data =  yf.download(tickers = tickers, 
    period = length, interval = interval, group_by = 'ticker',
    auto_adjust = True,
    prepost = False,
    threads = True,
    proxy = None
)

    data = data.loc[:, pd.IndexSlice[:, ['Close']]]

    columns = data.columns.droplevel(1)

    data.columns = columns 

    data.sort_index(axis = 1, inplace = True)
    #data = data.reset_index(drop = True)
    return data.dropna()

# %%
with open("sp100tickers.pickle", "rb") as f:
            tickers = pickle.load(f)
        
data = get_data(tickers,'1440d','1d')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 with open("sp100tickers.pickle", "rb") as f:
#       2             tickers = pickle.load(f)
#       4 data = get_data(tickers,'1440d','1d')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sp100tickers.pickle'

# %% [markdown]
# # Backtest Demo
# ## initialize a Backtest instance with data and strategy, in default:
# - initial_amount = 100000
# - has_tc = True (0.2% of transaction cost)

# %%
random_strat = Backtest(data[:2000],my_strategy, has_tc = False)

# %%
random_strat.backtest_full()
# Out:
# =================2019-04-01 09:30:00=================
# ---------------
# Buying:
# Ticker: wfc
# Shares: 100
# Price: 45.2882
# ---------------
# ---------------
# Buying:
# Ticker: mgm
# Shares: 100
# Price: 25.5639
# ---------------
# ---------------
# Buying:
# Ticker: ilmn
# Shares: 100
# Price: 314.96
# ---------------
# ---------------
# Buying:
# Ticker: mgm
# Shares: 100
# Price: 25.5639
# ---------------
# ---------------
# Buying:
# Ticker: s
# Shares: 100
# Price: 5.73
# ---------------
# ---------------
# Buying:
# Ticker: aapl
# Shares: 100
# Price: 46.831
# ---------------
# ---------------
# Buying:
# Ticker: googl
# Shares: 100
# Price: 1189.16
# ---------------
# ---------------
# Buying:
# Ticker: apc
# Shares: 100
# Price: 45.9276
# ---------------
# ---------------
# Buying:
# Ticker: mgm
# Shares: 100
# Price: 25.5639
# ---------------
# ---------------
# Buying:
# Ticker: mmm
# Shares: 100
# Price: 197.166
# ---------------
# Not enough cash to build a position for googl
# =================2019-04-01 10:00:00=================
# =================2019-04-01 10:30:00=================
# =================2019-04-01 11:00:00=================
# =================2019-04-01 11:30:00=================
# =================2019-04-01 12:00:00=================
# =================2019-04-01 12:30:00=================
# =================2019-04-01 13:00:00=================
# =================2019-04-01 13:30:00=================
# =================2019-04-01 14:00:00=================
# =================2019-04-01 14:30:00=================
# =================2019-04-01 15:00:00=================
# =================2019-04-01 15:30:00=================
# =================2019-04-01 16:00:00=================
# ---------------
# Selling
# Ticker: wfc
# Shares: 100
# Price: 45.5214
# ---------------
# ---------------
# Selling
# Ticker: mgm
# Shares: 300
# Price: 26.031
# ---------------
# ---------------
# Selling
# Ticker: ilmn
# Shares: 100
# Price: 316.838
# ---------------
# ---------------
# Selling
# Ticker: s
# Shares: 100
# Price: 5.62
# ---------------
# ---------------
# Selling
# Ticker: aapl
# Shares: 100
# Price: 46.9937
# ---------------
# ---------------
# Selling
# Ticker: apc
# Shares: 100
# Price: 45.7912
# ---------------
# ---------------
# Selling
# Ticker: mmm
# Shares: 100
# Price: 199.016
# ---------------
# =================2019-04-01 16:30:00=================
# =================2019-04-02 09:30:00=================
# ---------------
# Buying:
# Ticker: orcl
# Shares: 100
# Price: 52.6085
# ---------------
# ---------------
# Buying:
# Ticker: irm
# Shares: 100
# Price: 30.8913
# ---------------
# ---------------
# Buying:
# Ticker: xlnx
# Shares: 100
# Price: 126.697
# ---------------
# ---------------
# Buying:
# Ticker: hal
# Shares: 100
# Price: 28.7085
# ---------------
# ---------------
# Buying:
# Ticker: ma
# Shares: 100
# Price: 237.107
# ---------------
# ---------------
# Buying:
# Ticker: v
# Shares: 100
# Price: 155.909
# ---------------
# ---------------
# Buying:
# Ticker: ba
# Shares: 100
# Price: 380.348
# ---------------
# ---------------
# Buying:
# Ticker: antm
# Shares: 100
# Price: 282.496
# ---------------
# ---------------
# Buying:
# Ticker: antm
# Shares: 100
# Price: 282.496
# ---------------
# ---------------
# Buying:
# Ticker: sbux
# Shares: 100
# Price: 71.6556
# ---------------
# Not enough cash to build a position for ba
# Not enough cash to build a position for antm
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# =================2019-04-02 10:00:00=================
# =================2019-04-02 10:30:00=================
# =================2019-04-02 11:00:00=================
# =================2019-04-02 11:30:00=================
# =================2019-04-02 12:00:00=================
# =================2019-04-02 12:30:00=================
# =================2019-04-02 13:00:00=================
# =================2019-04-02 13:30:00=================
# =================2019-04-02 14:00:00=================
# =================2019-04-02 14:30:00=================
# =================2019-04-02 15:00:00=================
# =================2019-04-02 15:30:00=================
# =================2019-04-02 16:00:00=================
# ---------------
# Selling
# Ticker: orcl
# Shares: 100
# Price: 52.3282
# ---------------
# ---------------
# Selling
# Ticker: irm
# Shares: 100
# Price: 30.9779
# ---------------
# ---------------
# Selling
# Ticker: xlnx
# Shares: 100
# Price: 125.664
# ---------------
# ---------------
# Selling
# Ticker: hal
# Shares: 100
# Price: 28.5839
# ---------------
# ---------------
# Selling
# Ticker: ma
# Shares: 100
# Price: 236.78
# ---------------
# ---------------
# Selling
# Ticker: v
# Shares: 100
# Price: 156.097
# ---------------
# ---------------
# Selling
# Ticker: antm
# Shares: 100
# Price: 281.85
# ---------------
# ---------------
# Selling
# Ticker: sbux
# Shares: 100
# Price: 71.8779
# ---------------
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# =================2019-04-02 16:30:00=================
# =================2019-04-03 09:30:00=================
# ---------------
# Buying:
# Ticker: mchp
# Shares: 100
# Price: 87.1736
# ---------------
# ---------------
# Buying:
# Ticker: ma
# Shares: 100
# Price: 237.525
# ---------------
# ---------------
# Buying:
# Ticker: amzn
# Shares: 100
# Price: 1825.7
# ---------------
# ---------------
# Buying:
# Ticker: odp
# Shares: 100
# Price: 34.8518
# ---------------
# ---------------
# Buying:
# Ticker: avgo
# Shares: 100
# Price: 284.763
# ---------------
# ---------------
# Buying:
# Ticker: xom
# Shares: 100
# Price: 72.885
# ---------------
# ---------------
# Buying:
# Ticker: mpc
# Shares: 100
# Price: 55.4343
# ---------------
# ---------------
# Buying:
# Ticker: uri
# Shares: 100
# Price: 120.118
# ---------------
# ---------------
# Buying:
# Ticker: uaa
# Shares: 100
# Price: 21.5
# ---------------
# ---------------
# Buying:
# Ticker: luv
# Shares: 100
# Price: 52.3986
# ---------------
# Not enough cash to build a position for amzn
# =================2019-04-03 10:00:00=================
# =================2019-04-03 10:30:00=================
# =================2019-04-03 11:00:00=================
# =================2019-04-03 11:30:00=================
# =================2019-04-03 12:00:00=================
# =================2019-04-03 12:30:00=================
# =================2019-04-03 13:00:00=================
# =================2019-04-03 13:30:00=================
# =================2019-04-03 14:00:00=================
# =================2019-04-03 14:30:00=================
# =================2019-04-03 15:00:00=================
# =================2019-04-03 15:30:00=================
# =================2019-04-03 16:00:00=================
# ---------------
# Selling
# Ticker: mchp
# Shares: 100
# Price: 87.9528
# ---------------
# ---------------
# Selling
# Ticker: ma
# Shares: 100
# Price: 236.444
# ---------------
# ---------------
# Selling
# Ticker: odp
# Shares: 100
# Price: 35.8278
# ---------------
# ---------------
# Selling
# Ticker: avgo
# Shares: 100
# Price: 282.654
# ---------------
# ---------------
# Selling
# Ticker: xom
# Shares: 100
# Price: 72.2864
# ---------------
# ---------------
# Selling
# Ticker: mpc
# Shares: 100
# Price: 55.4067
# ---------------
# ---------------
# Selling
# Ticker: uri
# Shares: 100
# Price: 121.01
# ---------------
# ---------------
# Selling
# Ticker: uaa
# Shares: 100
# Price: 21.4
# ---------------
# ---------------
# Selling
# Ticker: luv
# Shares: 100
# Price: 52.1325
# ---------------
# =================2019-04-03 16:30:00=================
# =================2019-04-04 09:30:00=================
# ---------------
# Buying:
# Ticker: brk
# Shares: 100
# Price: 203.65
# ---------------
# ---------------
# Buying:
# Ticker: adbe
# Shares: 100
# Price: 270.66
# ---------------
# ---------------
# Buying:
# Ticker: fb
# Shares: 100
# Price: 176.45
# ---------------
# ---------------
# Buying:
# Ticker: jpm
# Shares: 100
# Price: 98.7655
# ---------------
# ---------------
# Buying:
# Ticker: bmy
# Shares: 100
# Price: 44.0368
# ---------------
# ---------------
# Buying:
# Ticker: cmcsa
# Shares: 100
# Price: 38.8813
# ---------------
# ---------------
# Buying:
# Ticker: goog
# Shares: 100
# Price: 1204.0
# ---------------
# ---------------
# Buying:
# Ticker: uaa
# Shares: 100
# Price: 21.425
# ---------------
# ---------------
# Buying:
# Ticker: ebay
# Shares: 100
# Price: 36.9932
# ---------------
# ---------------
# Buying:
# Ticker: avgo
# Shares: 100
# Price: 282.654
# ---------------
# Not enough cash to build a position for goog
# Not enough cash to build a position for avgo
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# =================2019-04-04 10:00:00=================
# =================2019-04-04 10:30:00=================
# =================2019-04-04 11:00:00=================
# =================2019-04-04 11:30:00=================
# =================2019-04-04 12:00:00=================
# =================2019-04-04 12:30:00=================
# =================2019-04-04 13:00:00=================
# =================2019-04-04 13:30:00=================
# =================2019-04-04 14:00:00=================
# =================2019-04-04 14:30:00=================
# =================2019-04-04 15:00:00=================
# =================2019-04-04 15:30:00=================
# =================2019-04-04 16:00:00=================
# ---------------
# Selling
# Ticker: brk
# Shares: 100
# Price: 204.1
# ---------------
# ---------------
# Selling
# Ticker: adbe
# Shares: 100
# Price: 267.76
# ---------------
# ---------------
# Selling
# Ticker: fb
# Shares: 100
# Price: 176.03
# ---------------
# ---------------
# Selling
# Ticker: jpm
# Shares: 100
# Price: 99.6244
# ---------------
# ---------------
# Selling
# Ticker: bmy
# Shares: 100
# Price: 44.1692
# ---------------
# ---------------
# Selling
# Ticker: cmcsa
# Shares: 100
# Price: 38.9681
# ---------------
# ---------------
# Selling
# Ticker: uaa
# Shares: 100
# Price: 22.12
# ---------------
# ---------------
# Selling
# Ticker: ebay
# Shares: 100
# Price: 37.0907
# ---------------
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# /Users/gideon/Desktop/General-Backtest/Backtest.py:299: RuntimeWarning: invalid value encountered in double_scalars
#   self.wa_cost_price = sum([i*j for i,j in self.purchase_history.items()])/self.shares
# =================2019-04-04 16:30:00=================
# =================2019-04-05 09:30:00=================
# ---------------
# Buying:
# Ticker: f
# Shares: 100
# Price: 8.6175
# ---------------
# ---------------
# Buying:
# Ticker: nwl
# Shares: 100
# Price: 14.219
# ---------------
# ---------------
# Buying:
# Ticker: khc
# Shares: 100
# Price: 29.7507
# ---------------
# ---------------
# Buying:
# Ticker: jpm
# Shares: 100
# Price: 99.8698
# ---------------
# ---------------
# Buying:
# Ticker: vlo
# Shares: 100
# Price: 77.0056
# ---------------
# ---------------
# Buying:
# Ticker: dnr
# Shares: 100
# Price: 2.22
# ---------------
# ---------------
# Buying:
# Ticker: fcx
# Shares: 100
# Price: 13.3536
# ---------------
# ---------------
# Buying:
# Ticker: rig
# Shares: 100
# Price: 9.1101
# ---------------
# ---------------
# Buying:
# Ticker: adi
# Shares: 100
# Price: 107.352
# ---------------
# ---------------
# Buying:
# Ticker: dal
# Shares: 100
# Price: 56.2185
# ---------------
# =================2019-04-05 10:00:00=================
# =================2019-04-05 10:30:00=================
# =================2019-04-05 11:00:00=================
# =================2019-04-05 11:30:00=================
# =================2019-04-05 12:00:00=================
# =================2019-04-05 12:30:00=================
# =================2019-04-05 13:00:00=================
# =================2019-04-05 13:30:00=================
# =================2019-04-05 14:00:00=================
# =================2019-04-05 14:30:00=================

# %% [markdown]
# # After backtest, check all historical transactions with transaction_history, a dataframe that recorded each bid, its transaction cost and pnl.

# %%
random_strat.transaction_history[:20]
# Out:
#                     dt ticker  type     price  shares    amount  cash_left  \
# 0  2019-04-01 09:30:00    wfc     1   45.2882     100   4528.82   95471.18
# 1  2019-04-01 09:30:00    mgm     1   25.5639     100   2556.39   92914.79
# 2  2019-04-01 09:30:00   ilmn     1  314.9600     100  31496.00   61418.79
# 3  2019-04-01 09:30:00    mgm     1   25.5639     100   2556.39   58862.40
# 4  2019-04-01 09:30:00      s     1    5.7300     100    573.00   58289.40
# 5  2019-04-01 09:30:00   aapl     1   46.8310     100   4683.10   53606.30
# 6  2019-04-01 09:30:00    apc     1   45.9276     100   4592.76   49013.54
# 7  2019-04-01 09:30:00    mgm     1   25.5639     100   2556.39   46457.15
# 8  2019-04-01 09:30:00    mmm     1  197.1660     100  19716.60   26740.55
# 9  2019-04-01 16:00:00    wfc     0   45.5214     100   4552.14   31292.69
# 10 2019-04-01 16:00:00    mgm     0   26.0310     300   7809.30   39101.99
# 11 2019-04-01 16:00:00   ilmn     0  316.8380     100  31683.80   70785.79
# 12 2019-04-01 16:00:00      s     0    5.6200     100    562.00   71347.79
# 13 2019-04-01 16:00:00   aapl     0   46.9937     100   4699.37   76047.16
# 14 2019-04-01 16:00:00    apc     0   45.7912     100   4579.12   80626.28
# 15 2019-04-01 16:00:00    mmm     0  199.0160     100  19901.60  100527.88
# 16 2019-04-02 09:30:00   orcl     1   52.6085     100   5260.85   95267.03
# 17 2019-04-02 09:30:00    irm     1   30.8913     100   3089.13   92177.90
# 18 2019-04-02 09:30:00   xlnx     1  126.6970     100  12669.70   79508.20
# 19 2019-04-02 09:30:00    hal     1   28.7085     100   2870.85   76637.35
#
#     transaction_cost     pnl
# 0                0.0    0.00
# 1                0.0    0.00
# 2                0.0    0.00
# 3                0.0    0.00
# 4                0.0    0.00
# 5                0.0    0.00
# 6                0.0    0.00
# 7                0.0    0.00
# 8                0.0    0.00
# 9                0.0   23.32
# 10               0.0  140.13
# 11               0.0  187.80
# 12               0.0  -11.00
# 13               0.0   16.27
# 14               0.0  -13.64
# 15               0.0  185.00
# 16               0.0    0.00
# 17               0.0    0.00
# 18               0.0    0.00
# 19               0.0    0.00

# %%
random_strat.transaction_history[random_strat.transaction_history['pnl']>10000]
# Out:
# Empty DataFrame
# Columns: [dt, ticker, type, price, shares, amount, cash_left, transaction_cost, pnl]
# Index: []

# %%
random_strat.transaction_history[(random_strat.transaction_history['ticker'] == 'amzn') & (random_strat.transaction_history['dt'].dt.day == 25)
                                ]
# Out:
# Empty DataFrame
# Columns: [dt, ticker, type, price, shares, amount, cash_left, transaction_cost, pnl]
# Index: []

# %%
print("Total Transaction cost:", random_strat.transaction_history['transaction_cost'].sum())
# Out:
# Total Transaction cost: 0.0

# %%
#histogram of pnl
random_strat.transaction_history['pnl'].hist(bins = 50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # The portfolio_tracker records the # of bids, length of positions, cash value, position value, total value at each ti.
# # The bah column is the value assuming we buy all the tickers when it begins

# %%
random_strat.portfolio_tracker[390:420]
# Out:
#                      dt  bid_count  position_count  cash_value  \
# 390 2019-04-01 15:59:00          0               7    26740.55
# 391 2019-04-01 16:00:00          7               0   100527.88
# 392 2019-04-01 16:01:00          0               0   100527.88
# 393 2019-04-01 16:02:00          0               0   100527.88
# 394 2019-04-01 16:03:00          0               0   100527.88
# 395 2019-04-01 16:04:00          0               0   100527.88
# 396 2019-04-01 16:05:00          0               0   100527.88
# 397 2019-04-01 16:06:00          0               0   100527.88
# 398 2019-04-01 16:07:00          0               0   100527.88
# 399 2019-04-01 16:08:00          0               0   100527.88
# 400 2019-04-01 16:09:00          0               0   100527.88
# 401 2019-04-01 16:10:00          0               0   100527.88
# 402 2019-04-01 16:11:00          0               0   100527.88
# 403 2019-04-01 16:12:00          0               0   100527.88
# 404 2019-04-01 16:13:00          0               0   100527.88
# 405 2019-04-01 16:14:00          0               0   100527.88
# 406 2019-04-01 16:15:00          0               0   100527.88
# 407 2019-04-01 16:16:00          0               0   100527.88
# 408 2019-04-01 16:17:00          0               0   100527.88
# 409 2019-04-01 16:18:00          0               0   100527.88
# 410 2019-04-01 16:19:00          0               0   100527.88
# 411 2019-04-01 16:20:00          0               0   100527.88
# 412 2019-04-01 16:21:00          0               0   100527.88
# 413 2019-04-01 16:22:00          0               0   100527.88
# 414 2019-04-01 16:23:00          0               0   100527.88
# 415 2019-04-01 16:24:00          0               0   100527.88
# 416 2019-04-01 16:25:00          0               0   100527.88
# 417 2019-04-01 16:26:00          0               0   100527.88
# 418 2019-04-01 16:27:00          0               0   100527.88
# 419 2019-04-01 16:28:00          0               0   100527.88
#
#      positions_value  total_value            bah
# 390          73790.7    100531.25  100311.120174
# 391              0.0    100527.88  100292.401151
# 392              0.0    100527.88  100241.569619
# 393              0.0    100527.88  100273.525735
# 394              0.0    100527.88  100239.468304
# 395              0.0    100527.88  100259.688514
# 396              0.0    100527.88  100244.157879
# 397              0.0    100527.88  100255.977896
# 398              0.0    100527.88  100230.394639
# 399              0.0    100527.88  100252.746728
# 400              0.0    100527.88  100289.990748
# 401              0.0    100527.88  100147.890287
# 402              0.0    100527.88  100146.029702
# 403              0.0    100527.88  100169.812738
# 404              0.0    100527.88  100202.613846
# 405              0.0    100527.88  100230.082027
# 406              0.0    100527.88  100203.280252
# 407              0.0    100527.88  100143.553771
# 408              0.0    100527.88  100142.778259
# 409              0.0    100527.88  100122.236450
# 410              0.0    100527.88  100116.153953
# 411              0.0    100527.88  100137.270193
# 412              0.0    100527.88  100166.663719
# 413              0.0    100527.88  100168.953501
# 414              0.0    100527.88  100179.669753
# 415              0.0    100527.88  100197.010221
# 416              0.0    100527.88  100332.478264
# 417              0.0    100527.88  100096.958709
# 418              0.0    100527.88  100464.546756
# 419              0.0    100527.88  100464.557789

# %%
plt.plot(random_strat.portfolio_tracker['total_value'], label = 'random_strat')
plt.plot(random_strat.portfolio_tracker['bah'],label = 'bah')
plt.legend()

# %% [markdown]
# #

# %% [markdown]
# # Upload to dashboard
# ## the upload_to_dashboard method will upload this graph to dashboard.
# ## make sure the crediential file "algo-trade-dashboard-80cae071e907.json" is under current directory, also install the related packages in requirements.txt
#
# ## to upload, call the function with the strategy name, if the name already exist in the gcloud, the previous data will be overwritten

# %%
random_strat.upload_to_dashboard("random_demo_0912")
# Out:
# Data uploaded.

# %% [markdown]
# # Check on dashboard:
# https://tigaji-algo-trade-dashboard-dashboard-gv8r0a.streamlitapp.com/
